# %%
import pandas as pd
import os
import requests
import io
import pandas as pd

# %%
path = "/mnt/c/Users/Samuel/Documents/python/data/HESA"

# %%
def download_files(path):

    files = [
    'https://www.hesa.ac.uk/data-and-analysis/providers/estates/table-1.csv',
    'https://www.hesa.ac.uk/data-and-analysis/providers/business-community/table-2a.csv',
    'https://www.hesa.ac.uk/data-and-analysis/providers/business-community/table-2b.csv',
    'https://www.hesa.ac.uk/data-and-analysis/providers/business-community/table-1.csv',
    'https://www.hesa.ac.uk/data-and-analysis/providers/business-community/table-3.csv',
    'https://www.hesa.ac.uk/data-and-analysis/providers/business-community/table-5.csv']

    for f in files:
        download = requests.get(f)
        with open(os.path.join(path,f.split("/")[-2],f.split("/")[-1]), 'w') as temp_file:
            temp_file.writelines(download.content.decode('utf-8'))

# %%
def read_files(path):
    file_metadata = []
    file_data = {}
    for i, filename in enumerate([os.path.join(a[0], b) for a in os.walk(path) for b in a[2]]):
        with open(filename,'r') as f:
            x = f.readlines()
        blank_lines = [0==len(l.replace(",","").replace("\n","")) for l in x]
        idx_metadata_end = blank_lines.index(True)
        header = idx_metadata_end + blank_lines[idx_metadata_end:].index(False)
        meta = pd.read_csv(filename, nrows = idx_metadata_end, header=None, index_col=0).iloc[:,0].to_frame(i)
        meta.index.name=None
        df = pd.read_csv(filename, header=header)
        file_data[i]=df
        file_metadata.append(meta)
    file_metadata = pd.concat(file_metadata, axis=1).T
    return file_data, file_metadata

# %%
files, meta = read_files(path)

# %%
pd.set_option("display.max_colwidth",-1)
meta["Title"].to_frame()
# Out:
#                                                                                                                                                                                    Title
# 0  Income from collaborative research involving public funding by academic year, type of income, source of public funding and HE provider
# 1  Business and community services by type of service, academic year, type of organisation and HE provider
# 2  Continuing Professional Development (CPD) and Continuing Education (CE) courses for business and the community by academic year and HE provider
# 3  Income from regeneration and development programmes by academic year, programme and HE provider
# 4  Social, community and cultural engagement: designated public events by academic year, type of event, nature of event, number of attendees, academic staff time (days) and HE provider
# 5  Estates management by academic year and HE provider

# %%
pd.set_option("display.max_rows",500)
categories = pd.Series(files[5]["Category marker"].unique()).to_frame("Categories")
providers = pd.Series(files[5]["HE Provider"].unique()).sort_values().to_frame("Providers")
pd.concat((categories,providers), axis=1).fillna("")
# Out:
#                                                                                               Categories  \
# 0    Total income (£)
# 1    Teaching income (£)
# 2    Research income (£)
# 3    Other non-residential income (£)
# 4    Non-residential income total (£)
# 5    Total expenditure (£)
# 6    Teaching student headcount
# 7    Research student headcount
# 8    Teaching student FTE
# 9    Research student FTE
# 10   Total staff FTE
# 11   Total number of sites
# 12   Total number of buildings
# 13   Non-residential number of buildings
# 14   Residential number of buildings
# 15   Total site area (hectares)
# 16   Total grounds area (hectares)
# 17   Grounds area water (hectares)
# 18   Grounds area listed or heritage (hectares)
# 19   Total playing fields area (hectares)
# 20   Total GIA (m2)
# 21   Non-residential GIA (m2)
# 22   Residential GIA (m2)
# 23   Total energy consumption (kWh)
# 24   Energy consumption burning oil (kWh)
# 25   Energy consumption fuel oil (kWh)
# 26   Energy consumption gas oil (kWh)
# 27   Energy consumption compressed natural gas (kWh)
# 28   Energy consumption liquefied natural gas (kWh)
# 29   Energy consumption liquefied petroleum gas (kWh)
# 30   Energy consumption natural gas excluding that used as input for a CHP unit (kWh)
# 31   Energy consumption natural gas used as input for a CHP unit (kWh)
# 32   Energy consumption other petroleum gas (kWh)
# 33   Energy consumption grid electricity (kWh)
# 34   Energy consumption coal (industrial) (kWh)
# 35   Energy consumption steam and hot water (kWh)
# 36   Energy consumption other onsite renewables (kWh)
# 37   Energy consumption lubricants (kWh)
# 38   Energy consumption biofuels (kWh)
# 39   Energy consumption heat consumed from onsite CHP (kWh)
# 40   Energy consumption electricity consumed from onsite CHP (kWh)
# 41   Energy consumption petroleum coke (kWh)
# 42   Energy consumption biomass (kWh)
# 43   Energy consumption onsite photovoltaic (kWh)
# 44   Energy consumption onsite wind (kWh)
# 45   Non-residential energy consumption total (kWh)
# 46   Residential energy consumption total (kWh)
# 47   Fuel used in HEP owned vehicles aviation spirit (litres)
# 48   Fuel used in HEP owned vehicles aviation turbine fuel (litres)
# 49   Fuel used in HEP owned vehicles biofuels (litres)
# 50   Fuel used in HEP owned vehicles diesel (litres)
# 51   Fuel used in HEP owned vehicles liquefied petroleum gas (litres)
# 52   Fuel used in HEP owned vehicles petrol (litres)
# 53   Total fuel used in HEP owned vehicles (litres)
# 54   Total generation of electricity exported to grid (kWh)
# 55   Total water consumption (m3)
# 56   Non-residential water consumption (m3)
# 57   Residential water consumption (m3)
# 58   Total scope 1 and 2 carbon emissions (Kg CO2e)
# 59   Scope 1 and 2 carbon emissions burning oil (Kg CO2e)
# 60   Scope 1 and 2 carbon emissions fuel oil (Kg CO2e)
# 61   Scope 1 and 2 carbon emissions gas oil (Kg CO2e)
# 62   Scope 1 and 2 carbon emissions compressed natural gas (Kg CO2e)
# 63   Scope 1 and 2 carbon emissions liquefied natural gas (Kg CO2e)
# 64   Scope 1 and 2 carbon emissions liquefied petroleum gas (Kg CO2e)
# 65   Scope 1 and 2 carbon emissions lubricants (Kg CO2e)
# 66   Scope 1 and 2 carbon emissions natural gas (Kg CO2e)
# 67   Scope 1 and 2 carbon emissions other petroleum gas (Kg CO2e)
# 68   Scope 1 and 2 carbon emissions grid electricity (Kg CO2e)
# 69   Scope 1 and 2 carbon emissions coal (industrial) (Kg CO2e)
# 70   Scope 1 and 2 carbon emissions steam and hot water (Kg CO2e)
# 71   Scope 1 and 2 carbon emissions biofuels (Kg CO2e)
# 72   Scope 1 and 2 carbon emissions petroleum coke (Kg CO2e)
# 73   Scope 1 and 2 carbon emissions biomass (Kg CO2e)
# 74   Scope 1 and 2 carbon emissions onsite photovoltaic (Kg CO2e)
# 117  Scope 3 carbon emissions from students commuting by coach (tonnes CO2e)
# 118  Scope 3 carbon emissions from students commuting by car (tonnes CO2e)
# 119  Scope 3 carbon emissions from students commuting by taxi (tonnes CO2e)
# 120  Scope 3 carbon emissions from students commuting by motorcycle or moped (tonnes CO2e)
# 121  Scope 3 carbon emissions from students commuting by ferry (tonnes CO2e)
# 122  Non-residential scope 3 carbon emissions from waste (tonnes CO2e)
# 123  Residential scope 3 carbon emissions from waste (tonnes CO2e)
# 124  Total scope 3 carbon emissions from waste (tonnes CO2e)
# 125  Non-residential method used to calculate scope 3 carbon emissions from waste
# 126  Residential method used to calculate scope 3 carbon emissions from waste
# 127  Total method used to calculate scope 3 carbon emissions from waste
# 128  Non-residential scope 3 carbon emissions from water supply (tonnes CO2e)
# 129  Residential scope 3 carbon emissions from water supply (tonnes CO2e)
# 130  Total scope 3 carbon emissions from water supply (tonnes CO2e)
# 131  Total scope 3 carbon emissions from wastewater treatment (tonnes CO2e)
# 132  Scope 3 carbon emissions from supply chain business services (tonnes CO2e)
# 133  Scope 3 carbon emissions from supply chain paper products (tonnes CO2e)
# 134  Scope 3 carbon emissions from supply chain other manufactured products (tonnes CO2e)
# 135  Scope 3 carbon emissions from supply chain manufactured fuels, chemicals, and gases (tonnes CO2e)
# 136  Scope 3 carbon emissions from supply chain food and catering (tonnes CO2e)
# 137  Scope 3 carbon emissions from supply chain construction (tonnes CO2e)
# 138  Scope 3 carbon emissions from supply chain information and communication technologies (tonnes CO2e)
# 139  Scope 3 carbon emissions from supply chain waste and water (tonnes CO2e)
# 140  Scope 3 carbon emissions from supply chain medical and precision instruments (tonnes CO2e)
# 141  Scope 3 carbon emissions from supply chain other procurement (tonnes CO2e)
# 142  Scope 3 carbon emissions from supply chain unclassified (tonnes CO2e)
# 143  Total carbon reduction target (%)
# 144  Total scope 1 and 2 emission baseline for 2005 (tonnes CO2e)
# 145  Total number of car parking spaces
# 146  Non-residential number of car parking spaces
# 147  Residential number of car parking spaces
# 148  Total percentage of renewable energy purchased through green tariffs (%)
# 149  Total energy generated onsite by CHP (kWh)
# 150  Total renewable energy generated onsite or offsite (kWh)
# 151  Use of renewable energy generated onsite or offsite where the ROCs are retained or not claimed (%)
# 152  Use of renewable energy generated onsite or offsite where the ROCs are sold (%)
# 153  Total waste mass (tonnes)
# 154  Total waste mass recycled (tonnes)
# 155  Total waste mass incineration (tonnes)
# 156  Total waste mass composting (tonnes)
# 157  Total waste mass anaerobic digestion (tonnes)
# 158  Total waste mass landfill (tonnes)
# 159  Total waste mass other (tonnes)
# 160  Total waste mass used to create energy (tonnes)
# 161  Non-residential waste mass total (tonnes)
# 162  Non-residential waste mass recycled (tonnes)
# 163  Non-residential waste mass incineration (tonnes)
# 164  Non-residential waste mass composting (tonnes)
# 165  Non-residential waste mass anaerobic digestion (tonnes)
# 166  Non-residential waste mass landfill (tonnes)
# 167  Non-residential waste mass other (tonnes)
# 168  Non-residential waste mass used to create energy (tonnes)
# 169  Residential waste mass total (tonnes)
# 170  Residential waste mass recycled (tonnes)
# 171  Residential waste mass incineration (tonnes)
# 172  Residential waste mass composting (tonnes)
# 173  Residential waste mass anaerobic digestion (tonnes)
# 174  Residential waste mass landfill (tonnes)
# 175  Residential waste mass other (tonnes)
# 176  Residential waste mass used to create energy (tonnes)
# 177  Other works waste mass total (tonnes)
# 178  Other works waste mass recycled (tonnes)
# 179  Other works waste mass incineration (tonnes)
# 180  Other works waste mass composting (tonnes)
# 181  Other works waste mass anaerobic digestion (tonnes)
# 182  Other works waste mass landfill (tonnes)
# 183  Other works waste mass other (tonnes)
# 184  Other works waste mass used to create energy (tonnes)
# 185  Environmental management system existence
# 186  Environmental management system external verification
# 187  Environmental management system external verification coverage
# 188  Environmental reporting total
# 189  Fairtrade accreditation existence
# 190  Percentage modal split for commuting by staff single occupancy car journey (%)
# 191  Percentage modal split for commuting by staff car share (%)
# 192  Percentage modal split for commuting by staff bus (%)
# 193  Percentage modal split for commuting by staff train (%)
# 194  Percentage modal split for commuting by staff cycle (%)
# 195  Percentage modal split for commuting by staff walk (%)
# 196  Percentage modal split for commuting by staff motorbike (%)
# 197  Percentage modal split for commuting by staff other (%)
# 198  Percentage modal split for commuting by students single occupancy car journey (%)
# 199  Percentage modal split for commuting by students car share (%)
# 200  Percentage modal split for commuting by students bus (%)
# 201  Percentage modal split for commuting by students train (%)
# 202  Percentage modal split for commuting by students cycle (%)
# 203  Percentage modal split for commuting by students walk (%)
# 204  Percentage modal split for commuting by students motorbike (%)
# 205  Percentage modal split for commuting by students other (%)
# 206  Total number of cycle spaces
# 207  Total water supply grey water and rain water (m3)
# 208  Total water borehole extraction (m3)
# 209  Borehole water used for irrigation (%)
# 210  Non-residential GIA in DEC or EPC category A (m2)
# 211  Non-residential GIA in DEC or EPC category B (m2)
# 212  Non-residential GIA in DEC or EPC category C (m2)
# 213  Non-residential GIA in DEC or EPC category D (m2)
# 214  Non-residential GIA in DEC or EPC category E (m2)
# 215  Non-residential GIA in DEC or EPC category F (m2)
# 216  Non-residential GIA in DEC or EPC category G (m2)
# 217  Residential GIA in DEC or EPC category A (m2)
# 218  Residential GIA in DEC or EPC category B (m2)
# 219  Residential GIA in DEC or EPC category C (m2)
# 220  Residential GIA in DEC or EPC category D (m2)
# 221  Residential GIA in DEC or EPC category E (m2)
# 222  Residential GIA in DEC or EPC category F (m2)
# 223  Residential GIA in DEC or EPC category G (m2)
# 224  EU Emissions Trading Scheme participation
# 225  EU Emissions Trading Scheme carbon allowance bought or sold (tonnes CO2e)
# 226  EU Emissions Trading Scheme carbon allowance (tonnes CO2e)
# 227  EU Emissions Trading Scheme cost (£)
#
#                                                 Providers
# 0    Anglia Ruskin University
# 111  The University of Cambridge
# 112  The University of East Anglia
# 113  The University of Edinburgh
# 114  The University of Essex
# 115  The University of Exeter
# 116  University of South Wales
# 117  The University of Glasgow
# 118  The University of Leeds
# 119  The University of Leicester
# 120  University of London (Institutes and activities)
# 121  The University of Manchester
# 122  Newcastle University
# 123  The University of the West of Scotland
# 124  University of Plymouth
# 125  The University of Reading
# 126  The University of St Andrews
# 127  The University of Stirling
# 128  The University of Strathclyde
# 129  The University of Sussex
# 130  University of Ulster
# 131  Bishop Grosseteste University
# 132  Cardiff University
# 133  The Royal Central School of Speech and Drama
# 134  Cranfield University
# 135  Edge Hill University
# 136  Guildhall School of Music and Drama
# 137  Newman University
# 138  Glyndŵr University
# 139  Royal Academy of Music
# 140  Royal Northern College of Music
# 141  University of Cumbria
# 142  St Mary's University, Twickenham
# 143  University of Chester
# 144  University of Abertay Dundee
# 145  The University of Bath
# 146  University of Derby
# 147  The University of Dundee
# 148  Cardiff Metropolitan University
# 149  Swansea University
# 150  Aberystwyth University
# 151  Bangor University
# 152  University of Wales Trinity Saint David
# 153  Stranmillis University College
# 154  Trinity Laban Conservatoire of Music and Dance
# 155  St Mary's University College
# 156  Falmouth University
# 157  University of Suffolk
# 158  University of St Mark and St John
# 159  Harper Adams University
# 160  Heythrop College
# 161
# 162
# 163
# 164
# 165
# 166
# 167
# 168
# 169
# 170
# 171
# 172
# 173
# 174
# 175
# 176
# 177
# 178
# 179
# 180
# 181
# 182
# 183
# 184
# 185
# 186
# 187
# 188
# 189
# 190
# 191
# 192
# 193
# 194
# 195
# 196
# 197
# 198
# 199
# 200
# 201
# 202
# 203
# 204
# 205
# 206
# 207
# 208
# 209
# 210
# 211
# 212
# 213
# 214
# 215
# 216
# 217
# 218
# 219
# 220
# 221
# 222
# 223
# 224
# 225
# 226
# 227

# %%
tmp = pd.Series(files[5]["Category marker"].unique()).to_frame("category")
tmp["units"] = tmp["category"].str.split("(").apply(lambda x : x[-1][:-1] if len (x)>1 else "")
tmp["category"] = tmp["category"].str.split("(").apply(lambda x : "(".join(x[:-1]) if len(x)>1 else x[0])
lcat = tmp["category"].str.lower().str

tmp["clss_carbon"] = lcat.contains("carbon emissions")
tmp["clss_renewable"] = lcat.contains("renewable energy")
tmp["clss_water"] = lcat.contains("water consumption") | lcat.contains("wastewater")
tmp["clss_waste"] = lcat.contains("waste mass")
tmp["clss_income"] = lcat.contains("income")
tmp["clss_expenditure"] = lcat.contains("expenditure")
tmp["clss_headcount"] = lcat.contains("headcount") | lcat.contains("fte")
tmp["clss_commuting"] = lcat.contains("commuting")
tmp["clss_energy"] = lcat.contains("energy consumption")
tmp["clss_fuel"] = lcat.contains("fuel used")
tmp["clss_gia"] = lcat.contains("gia")
tmp["clss_parking"] = lcat.contains("parking") | lcat.contains("cycle spaces")
tmp["clss_other"] = ~tmp[[x for x in tmp.columns if "clss_" in x]].any(axis=1)
tmp[tmp["clss_other"]]

tmp[tmp[[x for x in tmp.columns if "clss_" in x]].sum(axis=1)>1]
# Out:
#                                                                      category  \
# 102  Scope 3 carbon emissions from staff commuting by air
# 103  Scope 3 carbon emissions from staff commuting by rail
# 104  Scope 3 carbon emissions from staff commuting by trams
# 105  Scope 3 carbon emissions from staff commuting by underground
# 106  Scope 3 carbon emissions from staff commuting by public bus
# 107  Scope 3 carbon emissions from staff commuting by coach
# 108  Scope 3 carbon emissions from staff commuting by car
# 109  Scope 3 carbon emissions from staff commuting by taxi
# 110  Scope 3 carbon emissions from staff commuting by motorcycle or moped
# 111  Scope 3 carbon emissions from staff commuting by ferry
# 112  Scope 3 carbon emissions from students commuting by air
# 113  Scope 3 carbon emissions from students commuting by rail
# 114  Scope 3 carbon emissions from students commuting by trams
# 115  Scope 3 carbon emissions from students commuting by underground
# 116  Scope 3 carbon emissions from students commuting by public bus
# 117  Scope 3 carbon emissions from students commuting by coach
# 118  Scope 3 carbon emissions from students commuting by car
# 119  Scope 3 carbon emissions from students commuting by taxi
# 120  Scope 3 carbon emissions from students commuting by motorcycle or moped
# 121  Scope 3 carbon emissions from students commuting by ferry
# 131  Total scope 3 carbon emissions from wastewater treatment
#
#            units  clss_carbon  clss_renewable  clss_water  clss_waste  \
# 102  tonnes CO2e  True         False           False       False
# 103  tonnes CO2e  True         False           False       False
# 104  tonnes CO2e  True         False           False       False
# 105  tonnes CO2e  True         False           False       False
# 106  tonnes CO2e  True         False           False       False
# 107  tonnes CO2e  True         False           False       False
# 108  tonnes CO2e  True         False           False       False
# 109  tonnes CO2e  True         False           False       False
# 110  tonnes CO2e  True         False           False       False
# 111  tonnes CO2e  True         False           False       False
# 112  tonnes CO2e  True         False           False       False
# 113  tonnes CO2e  True         False           False       False
# 114  tonnes CO2e  True         False           False       False
# 115  tonnes CO2e  True         False           False       False
# 116  tonnes CO2e  True         False           False       False
# 117  tonnes CO2e  True         False           False       False
# 118  tonnes CO2e  True         False           False       False
# 119  tonnes CO2e  True         False           False       False
# 120  tonnes CO2e  True         False           False       False
# 121  tonnes CO2e  True         False           False       False
# 131  tonnes CO2e  True         False           True        False
#
#      clss_income  clss_expenditure  clss_headcount  clss_commuting  \
# 102  False        False             False           True
# 103  False        False             False           True
# 104  False        False             False           True
# 105  False        False             False           True
# 106  False        False             False           True
# 107  False        False             False           True
# 108  False        False             False           True
# 109  False        False             False           True
# 110  False        False             False           True
# 111  False        False             False           True
# 112  False        False             False           True
# 113  False        False             False           True
# 114  False        False             False           True
# 115  False        False             False           True
# 116  False        False             False           True
# 117  False        False             False           True
# 118  False        False             False           True
# 119  False        False             False           True
# 120  False        False             False           True
# 121  False        False             False           True
# 131  False        False             False           False
#
#      clss_energy  clss_fuel  clss_gia  clss_parking  clss_other
# 102  False        False      False     False         False
# 103  False        False      False     False         False
# 104  False        False      False     False         False
# 105  False        False      False     False         False
# 106  False        False      False     False         False
# 107  False        False      False     False         False
# 108  False        False      False     False         False
# 109  False        False      False     False         False
# 110  False        False      False     False         False
# 111  False        False      False     False         False
# 112  False        False      False     False         False
# 113  False        False      False     False         False
# 114  False        False      False     False         False
# 115  False        False      False     False         False
# 116  False        False      False     False         False
# 117  False        False      False     False         False
# 118  False        False      False     False         False
# 119  False        False      False     False         False
# 120  False        False      False     False         False
# 121  False        False      False     False         False
# 131  False        False      False     False         False
