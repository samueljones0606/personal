# %% [markdown]
# # Pokemon Data

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import datetime
import seaborn as sns
import plotly as py
from scipy.stats import norm

import os
# %matplotlib inline

# %%
# Read in all the pokemon data to a dataframe
path = os.path.join(os.getcwd(),"..","data","","pokemon.csv")
data = pd.read_csv(path, index_col='name')

# %%
data.sample(5)
# Out:
#                                                  abilities  against_bug  \
# name
# Hitmonchan        ['Keen Eye', 'Iron Fist', 'Inner Focus']          0.5
# Roselia     ['Natural Cure', 'Poison Point', 'Leaf Guard']          1.0
# Porygon2                 ['Trace', 'Download', 'Analytic']          1.0
# Furfrou                                       ['Fur Coat']          1.0
# Gulpin          ['Liquid Ooze', 'Sticky Hold', 'Gluttony']          0.5
#
#             against_dark  against_dragon  against_electric  against_fairy  \
# name
# Hitmonchan           0.5             1.0               1.0            2.0
# Roselia              1.0             1.0               0.5            0.5
# Porygon2             1.0             1.0               1.0            1.0
# Furfrou              1.0             1.0               1.0            1.0
# Gulpin               1.0             1.0               1.0            0.5
#
#             against_fight  against_fire  against_flying  against_ghost  \
# ...

# %%
", ".join(data.columns)
# Out:
# 'abilities, against_bug, against_dark, against_dragon, against_electric, against_fairy, against_fight, against_fire, against_flying, against_ghost, against_grass, against_ground, against_ice, against_normal, against_poison, against_psychic, against_rock, against_steel, against_water, attack, base_egg_steps, base_happiness, base_total, capture_rate, classfication, defense, experience_growth, height_m, hp, japanese_name, percentage_male, pokedex_number, sp_attack, sp_defense, speed, type1, type2, weight_kg, generation, is_legendary'

# %%
# %matplotlib inline

# %%
interesting_columns = ["speed","base_egg_steps","attack","defense","sp_attack","sp_defense"]
data2 = data[interesting_columns]
data2.astype(float).head()
# Out:
#             speed  base_egg_steps  attack  defense  sp_attack  sp_defense
# name
# Bulbasaur    45.0          5120.0    49.0     49.0       65.0        65.0
# Ivysaur      60.0          5120.0    62.0     63.0       80.0        80.0
# Venusaur     80.0          5120.0   100.0    123.0      122.0       120.0
# Charmander   65.0          5120.0    52.0     43.0       60.0        50.0
# Charmeleon   80.0          5120.0    64.0     58.0       80.0        65.0
